# %%
import math
import scipy as sp
import matplotlib.pyplot as plt
from numpy import *

v=40
g=9.8
m=68.1
t=10
fc=0
x1=12
x2=16
xrf=0
xrb=0
i=0
fx=0
ft=0
x=[]
y=[]
k=[]
l=[1,0,-1]

fh=(g*m/x1)*(1-pow(math.exp(1),-(x1/m)*t))-v
fk=(g*m/x2)*(1-pow(math.exp(1),-(x2/m)*t))-v
ft=fh*fk
fu=0
Ev=0
Et=0
Ea=0

e2=0
e1=0
if ft<0:  
    print("metodo falsa posicion ");
    print("     iteracion"+"            Ea"+"            Et");
    while True:
        e2=xrf
        fc=(g*m/x1)*(1-pow(math.exp(1),-(x1/m)*t))-v
        fu=(g*m/(x2))*(1-pow(math.exp(1),-((x2)/m)*t))-v
        xrf=x2-(fu*(x1-x2)/(fc-fu))
        ft=fc*fu
        e1=xrf
        #print("Error verdadero");
        Ev=14.780203831661057 
        Et=(Ev/xrf)*100
        #print("Error aproximado");
        if e2==0:
            Ea=0
        else:
            Ea=((xrf-e2)/xrf)*100
        if ft>0:
            print ("{0:15} | {1:15} | {2:15} ".format((i),round(Ea,4),round(Et,4)));
            x1=xrf
        elif ft<0:
            print ("{0:15} | {1:15} | {2:15} ".format((i),round(Ea,4),round(Et,4)));
            x2=xrf 
        elif ft==0:
            print ("{0:15} | {1:15} | {2:15} ".format((i),round(Ea,4),round(Et,4)));
            break
        #print(xr);
        if i>100:
            break
        i=i+1 
       

    print("metodo biseccion ");
    print("      iteracion"+"              Ea"+"              Et");
    x1b=1
    x2b=16   
    i=0
    e2=0
    e1=0
    Et=0
    Ea=0
    while True:
        e2=e1
        xrb=(x1b+x2b)/2
        fc=(g*m/x1b)*(1-pow(math.exp(1),-(x1b/m)*t))-v
        fx=(g*m/xrb)*(1-pow(math.exp(1),-(xrb/m)*t))-v
        fu=(g*m/(i+1))*(1-pow(math.exp(1),-((i+1)/m)*t))-v
        ft=fc*fx
        e1=xrb
        #print("Error verdadero");
        Ev=14.780203831661057 
        Et=(Ev/xrb)*100
        #print("Error aproximado");
        if e2==0:
            Ea=0
        else:
            Ea=((xrb-e2)/xrb)*100
            
        if ft>0:
            print ("{0:15} | {1:15} | {2:15} ".format((i),round(Ea,4),round(Et,4)));
            x1b=xrb
        elif ft<0:
            print ("{0:15} | {1:15} | {2:15} ".format((i),round(Ea,4),round(Et,4)));
            x2b=xrb
        elif ft==0:
            print ("{0:15} | {1:15} | {2:15} ".format((i),round(Ea,4),round(Et,4)));
            break
        #print(xr);
        if i>100:
            break
        i=i+1
# Out:
# metodo falsa posicion
#      iteracion            Ea            Et
#               0 |             0.0 |         99.1208
#               1 |         -0.7916 |         99.9054
#               2 |         -0.0845 |         99.9899
#               3 |          -0.009 |         99.9989
#               4 |          -0.001 |         99.9999
#               5 |         -0.0001 |           100.0
#               6 |            -0.0 |           100.0
#               7 |            -0.0 |           100.0
#               8 |            -0.0 |           100.0
#               9 |            -0.0 |           100.0
#              10 |            -0.0 |           100.0
#              11 |            -0.0 |           100.0
#              12 |            -0.0 |           100.0
#              13 |            -0.0 |           100.0
#              14 |            -0.0 |           100.0
#              15 |            -0.0 |           100.0
#              16 |             0.0 |           100.0
# metodo biseccion
#       iteracion              Ea              Et
#               0 |             0.0 |        184.7525
#               1 |             0.0 |        123.1684
#               2 |             0.0 |        105.5729
