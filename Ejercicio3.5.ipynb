# %%
import math
val=6.737947*math.pow(10, -3)
Val2=0
x=5
print("{0:10} | {1:22} | {2:25} | {3:25} |".format("Termino", "E^x Aprox", "Et", "Ea"));    
for i in range(20):
    if(i%2!=0):
        Xaprox=-(math.pow(x, i)/math.factorial(i))
    else:
        Xaprox=(math.pow(x, i)/math.factorial(i))
    ant=Val2
    Val2+=Xaprox
    Ever=val-Val2
    Et=(Ever/Val2)*100
    Ea=((Val2-ant)/Val2)*100
    print("{0:10} | {1:22} | {2:25} | {3:25} |".format(i,Val2,str(Et)+" %",str(Ea)+" %"));

Val2=0
Val3=0
print ("1/E^x")
print("{0:10} | {1:20} | {2:25} | {3:25} |".format("Termino", "E^x Aprox", "Et", "Ea"));
for i in range(20):
    Xaprox=(math.pow(x, i)/math.factorial(i))
    ant=Val3
    Val2+=Xaprox
    Val3=1/Val2
    Ever=math.fabs(val-Val3)
    Et=(Ever/Val3)*100
    Ea=((Val3-ant)/Val3)*100
    print("{0:10} | {1:20} | {2:25} | {3:25} |".format(i,Val3,str(Et)+" %",str(Ea)+" %"));
# Out:
# Termino    | E^x Aprox              | Et                        | Ea                        |
#          0 |                    1.0 | -99.3262053 %             | 100.0 %                   |
#          1 |                   -4.0 | -100.168448675 %          | 125.0 %                   |
#          2 |                    8.5 | -99.9207300353 %          | 147.058823529 %           |
#          3 |         -12.3333333333 | -100.054632003 %          | 168.918918919 %           |
#          4 |          13.7083333333 | -99.950847803 %           | 189.969604863 %           |
#          5 |         -12.3333333333 | -100.054632003 %          | 211.148648649 %           |
#          6 |          9.36805555556 | -99.9280752878 %          | 231.653076353 %           |
#          7 |         -6.13293650794 | -100.10986494 %           | 252.74991912 %            |
#          8 |          3.55518353175 | -99.8104754103 %          | 272.506888974 %           |
# ...
